# %% [markdown]
# #### ASSESSMENT - 1

# %%
import numpy as np;
import pandas as pd;

# %% [markdown]
# #### (1) Import pandas and read in the banklist.csv file into a dataframe called banks.

# %%
Banks = pd.read_csv(r'C:\Users\44743\Downloads\banklist.csv')
Banks
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 548                                 Superior Bank, FSB            Hinsdale
# 549                                Malta National Bank               Malta
# 550                    First Alliance Bank & Trust Co.          Manchester
# 551                  National State Bank of Metropolis          Metropolis
# 552                                   Bank of Honolulu            Honolulu
#
# ...

# %% [markdown]
# #### (2) Show the head of the dataframe.

# %%
Banks.head()
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date
# 0   1802            United Fidelity Bank, fsb    26-May-17    26-Jul-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17    26-Jul-17
# 2  58302                         Whitney Bank    28-Apr-17    26-Jul-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4  19328                  State Bank of Texas    27-Jan-17    18-May-17

# %% [markdown]
# #### (3) What are the column names?

# %%
Banks.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %% [markdown]
# #### (4) How many States (ST) are represented in this data set?

# %%
Banks.ST.unique()
# Out:
# array(['IL', 'WI', 'LA', 'UT', 'NJ', 'AR', 'GA', 'PA', 'TN', 'WA', 'CO',
#        'PR', 'FL', 'MN', 'CA', 'MD', 'OK', 'OH', 'SC', 'VA', 'ID', 'TX',
#        'CT', 'AZ', 'NV', 'NC', 'KY', 'MO', 'KS', 'AL', 'MI', 'IN', 'IA',
#        'NE', 'MS', 'NM', 'OR', 'NY', 'MA', 'SD', 'WY', 'WV', 'NH', 'HI'],
#       dtype=object)

# %% [markdown]
# #### (5) Get a list or array of all the states in the data set.

# %%
states_list = Banks['ST'].unique().tolist()
states_array = Banks['ST'].unique()

print("List of States:", states_list)
print("\nArray of States:", states_array)
# Out:
# List of States: ['IL', 'WI', 'LA', 'UT', 'NJ', 'AR', 'GA', 'PA', 'TN', 'WA', 'CO', 'PR', 'FL', 'MN', 'CA', 'MD', 'OK', 'OH', 'SC', 'VA', 'ID', 'TX', 'CT', 'AZ', 'NV', 'NC', 'KY', 'MO', 'KS', 'AL', 'MI', 'IN', 'IA', 'NE', 'MS', 'NM', 'OR', 'NY', 'MA', 'SD', 'WY', 'WV', 'NH', 'HI']
#
# Array of States: ['IL' 'WI' 'LA' 'UT' 'NJ' 'AR' 'GA' 'PA' 'TN' 'WA' 'CO' 'PR' 'FL' 'MN'
#  'CA' 'MD' 'OK' 'OH' 'SC' 'VA' 'ID' 'TX' 'CT' 'AZ' 'NV' 'NC' 'KY' 'MO'
#  'KS' 'AL' 'MI' 'IN' 'IA' 'NE' 'MS' 'NM' 'OR' 'NY' 'MA' 'SD' 'WY' 'WV'
#  'NH' 'HI']

# %% [markdown]
# #### (6) What are the top 5 states with the most failed banks?

# %%
top_5_states = Banks['ST'].value_counts().head()

print("Top 5 states with the most failed banks:")
print(top_5_states)
# Out:
# Top 5 states with the most failed banks:
# ST
# GA    93
# FL    75
# IL    68
# CA    41
# MN    23
# Name: count, dtype: int64

# %% [markdown]
# #### (7) What are the top 5 acquiring institutions?

# %%
Top_5_acquirng_institutions = Banks.groupby('Acquiring Institution').size().sort_values(ascending=False).head()
print("\nTop 5 acquiring institutions:")
print(Top_5_acquirng_institutions)
# Out:
# Top 5 acquiring institutions:
# Acquiring Institution
# No Acquirer                            31
# State Bank and Trust Company           12
# First-Citizens Bank & Trust Company    11
# Ameris Bank                            10
# U.S. Bank N.A.                          9
# dtype: int64

# %% [markdown]
# #### (8) How many banks has the State Bank of Texas acquired? How many of them were actually in Texas?

# %%
Banks
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 548                                 Superior Bank, FSB            Hinsdale
# 549                                Malta National Bank               Malta
# 550                    First Alliance Bank & Trust Co.          Manchester
# 551                  National State Bank of Metropolis          Metropolis
# 552                                   Bank of Honolulu            Honolulu
#
# ...

# %%
state_bank_of_texas_acquisitions = Banks[Banks['Acquiring Institution'] == 'State Bank of Texas']
total_acquisitions = len(state_bank_of_texas_acquisitions)
texas_acquisitions = len(state_bank_of_texas_acquisitions[state_bank_of_texas_acquisitions['ST'] == 'TX'])

print("\nNumber of banks acquired by State Bank of Texas:", total_acquisitions)
print("Number of Texas banks acquired by State Bank of Texas:", texas_acquisitions)
# Out:
# Number of banks acquired by State Bank of Texas: 3
# Number of Texas banks acquired by State Bank of Texas: 1

# %% [markdown]
# #### (9) What is the most common city in California for a bank to fail in?

# %%
most_common_city_ca = Banks[Banks['ST'] == 'CA']['City'].value_counts().idxmax()
print("The most common city in California for a bank to fail in:", most_common_city_ca)
# Out:
# The most common city in California for a bank to fail in: Los Angeles

# %% [markdown]
# #### ASSESSMENT 2

# %%
import numpy as np;
import pandas as pd;
import matplotlib.pyplot as plt;
import seaborn as sns;

# %%
H_A_M_S = pd.read_csv(r"C:\Users\44743\Downloads\historical_automobile_sales.csv")
H_A_M_S
# Out:
#            Date  Year Month  Recession  Consumer_Confidence  \
# 0     1/31/1980  1980   Jan          1               108.24
# 1     2/29/1980  1980   Feb          1                98.75
# 2     3/31/1980  1980   Mar          1               107.48
# 3     4/30/1980  1980   Apr          1               115.01
# 4     5/31/1980  1980   May          1                98.72
# ..          ...   ...   ...        ...                  ...
# 523   8/31/2023  2023   Aug          0               103.36
# 524   9/30/2023  2023   Sep          0               101.55
# 525  10/31/2023  2023   Oct          0               124.66
# 526  11/30/2023  2023   Nov          0                97.09
# 527  12/31/2023  2023   Dec          0                95.92
#
#      Seasonality_Weight      Price  Advertising_Expenditure  Competition  \
# 0                  0.50  27483.571                     1558            7
# 1                  0.75  24308.678                     3048            4
# ...

# %% [markdown]
# #### (1) Develop a Line chart using the functionality of pandas to show how automobile sales fluctuate from year to year.

# %%
H_A_M_S.groupby('Year')['Automobile_Sales'].sum().plot(kind='line', title='Yearly Automobile Sales', xlabel='Year', ylabel='Automobile Sales', figsize=(10, 6))
plt.grid()
plt.show()

# %% [markdown]
# #### (2) Plot different lines for categories of vehicle type and analyze the trend to answer the question Is there a noticeable difference in sales trends between different vehicle types during recession periods?

# %%
plt.figure(figsize=(14, 8))
sns.lineplot(data=H_A_M_S, x='Year', y='Automobile_Sales', hue='Vehicle_Type', style='Recession', markers=True, dashes=False)
plt.title('Automobile Sales Trends by Vehicle Type During Recession Periods', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Automobile Sales', fontsize=12)
plt.legend(title='Vehicle Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### (3) Use the functionality of Seaborn Library to create a visualization to compare the sales trend per vehicle type for a recession period with a non- recession period.

# %%
plt.figure(figsize=(14, 8))
sns.lineplot(data=H_A_M_S, x='Year', y='Automobile_Sales', hue='Vehicle_Type', style='Recession', markers=True, dashes=True)
plt.title('Sales Trend per Vehicle Type: Recession vs Non-Recession Periods', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Automobile Sales', fontsize=12)
plt.legend(title='Vehicle Type & Recession', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### (4) Now you want to compare the sales of different vehicle types during a recession and a non-recession period

# %%
# Grouping data by Recession and Vehicle_Type for average Automobile_Sales
avg_sales = H_A_M_S.groupby(['Recession', 'Vehicle_Type'])['Automobile_Sales'].mean().reset_index()
# Plotting the bar chart
plt.figure(figsize=(14, 8))
sns.barplot(data=avg_sales, x='Vehicle_Type', y='Automobile_Sales', hue='Recession')
plt.title('Average Automobile Sales by Vehicle Type During Recession and Non-Recession Periods', fontsize=16)
plt.xlabel('Vehicle Type', fontsize=12)
plt.ylabel('Average Automobile Sales', fontsize=12)
plt.legend(title='Recession', labels=['Non-Recession', 'Recession'], bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
